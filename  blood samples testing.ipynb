# %%
from fastai.vision import *

# %%
#folder='EOSINOPHIL'
#folder='LYMPHOCYTE'
#folder='MONOCYTE'
#folder='NEUTROPHIL'

# %%
#path=Path('D:\\fastai\\data\\bloodcells\\dataset2-master\\train')
#dest=path/folder
#dest

# %%
classes=['eosinophil','lymphocyte','monocyte','neutrophil']
classes
#in this sttep i am creating the diiferent classes which i am feeding it to my neuralnetwork..
# Out:
# ['eosinophil', 'lymphocyte', 'monocyte', 'neutrophil']

# %%
for c in classes:
    print (c)
    verify_images(path/c,delete=True,max_size=500)
# now i am checking whether the image is  loading or not...
# that is whether the image is able to open or not...
# Out:
# eosinophil
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2497' class='' max='2497', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2497/2497 00:05<00:00]
#     </div>
# lymphocyte
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
# ...

# %%
np.random.seed(42)
data=ImageDataBunch.from_folder(
    path,
    train='.',
    valid_pct=0.3,
    ds_tfms=get_transforms(),
    size=224,
    num_workers=0
).normalize(imagenet_stats)
#now based on the imagenet stats i have created the data bunch which is used for the feeding of my neural network..
#first parameter--> path i am setting the path to the databunch which i have created..
#train --> where it will train on all the classes ...
#valid_pct means it will create a validation set where it means the computer or the neural network 
#doesnt feed these images into the net...
#transforms  means it actually transforms the image according to the standard of imagenet..
#size: The default size which we supply to feed the neural network.. is 224 that is the fixed size to feed..

# %%
data.classes,data.c,data.path
# Out:
# (['eosinophil', 'lymphocyte', 'monocyte', 'neutrophil'],
#  4,
#  WindowsPath('D:/fastai/data/bloodcells/dataset2-master/train'))

# %%
data.show_batch(rows=5)

# %%
 learn=cnn_learner??

# %%
learn=cnn_learner(data,models.resnet34,metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 27:03 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.001690</td>
#       <td>0.510358</td>
#       <td>0.201875</td>
#       <td>07:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.513291</td>
#       <td>0.223766</td>
#       <td>0.080013</td>
#       <td>06:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.327194</td>
#       <td>0.154748</td>
#       <td>0.051557</td>
#       <td>06:38</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.272120</td>
#       <td>0.137191</td>
#       <td>0.044526</td>
#       <td>06:32</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.export()

# %%
defaults.device=torch.device('cpu')

# %%
img=open_image('D:\\fastai\\data\\testblood\\TEST_SIMPLE\EOSINOPHIL\\_7_2284.jpeg')
img
# Out:
# Image (3, 240, 320)

# %%
learn=load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category eosinophil
